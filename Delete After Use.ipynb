# %%
import pandas as pd
df = pd.read_excel("111597639_1572146776530.xls")

# %%
df
# Out:
#     HDFC BANK Ltd.                                      Page No .:   1                                          Statement of accounts  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                 MR      SOMIL SHARMA
# 5                   CO6NIHANT TECHNOLOGY SOLUTION CO P
# 6                  BLDG CNADOOK TECHSPACE SEC TOWER B1
# 7                  2ND FL PLOT DH1 DH2 RAJARHAT NEWTOW
# 8                                       KOLKATA 700156
# 9                                    WEST BENGAL INDIA
# 10                                                 NaN
# 11                                     JOINT HOLDERS :
# 12                                                 NaN
# 13                           Nomination  :  Registered
# 14   Statement From  :  01/09/2019         To  :  2...
# ...
