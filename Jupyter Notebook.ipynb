# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.__version__
# Out:
# '0.24.2'

# %% [raw]
# Modes in Jupyter Notebooks (states of codeblocks)

# %% [markdown]
# Markdown mode: Useful for everything outside of code, eg : for generating headers/comments, embedding videos, images and audio files

# %% [raw]
# Command mode: operates on the top layer of the notebook, triggered by pressing the Esc key, allows us to use keyboard shortcuts, commands issued in command mode are not interpreted as commands

# %%
# Adding rows

# %%
# Generating Output

2 + 3
# Out:
# 5

# %%
# Browsing Jupyter Shortuts using Esc+H

# %%
# Dataframe Output 

pd.read_csv('jamesbond.csv')
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
# Restart Kernel, whenever code is stuck in an infinite loop or cell blocks won't execute
