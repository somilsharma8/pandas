# %%
import pandas as pd

# %%
week1 = pd.read_csv('Restaurant - Week 1 Sales.csv')
week1
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 220          147        8
# 221          745        4
# 222          184        3
# ...

# %%
week2 = pd.read_csv('Restaurant - Week 1 Satisfaction.csv')
week2
# Out:
#      Satisfaction Rating
# 0                      2
# 1                      7
# 2                      3
# 3                      7
# 4                     10
# 5                      3
# 6                      2
# 7                      5
# 8                     10
# 9                      7
# 10                     7
# 11                     5
# 12                     3
# 13                     2
# 14                     7
# 15                     4
# 16                     6
# 17                     1
# 18                     5
# 19                     5
# 20                     3
# 21                     2
# 22                     3
# 23                    10
# 24                     4
# 25                     9
# 26                     1
# 27                     4
# 28                     4
# 29                     9
# ..                   ...
# 220                    3
# 221                    8
# 222                    4
# 223                    2
# 224                    5
# ...

# %%
customers = pd.read_csv('Restaurant - Customers.csv')
customers
# Out:
#        ID First Name Last Name  Gender        Company  \
# 0       1     Joseph   Perkins    Male        Dynazzy
# 1       2   Jennifer   Alvarez  Female           DabZ
# 2       3      Roger     Black    Male        Tagfeed
# 3       4     Steven     Evans    Male           Fatz
# 4       5       Judy  Morrison  Female        Demivee
# 5       6     Amanda    Howell  Female  Thoughtbridge
# 6       7     Johnny      Reid    Male    Babblestorm
# 7       8    Frances     Adams  Female       Dabshots
# 8       9    Gregory   Chapman    Male           Eayo
# 9      10     Steven      Ryan    Male        Twinder
# 10     11    Michael  Reynolds    Male         Meevee
# 11     12       Lois   Watkins  Female           Mydo
# 12     13       Ruth   Alvarez  Female    Twitterlist
# 13     14       Adam      Ryan    Male       Photojam
# 14     15      Jesse  Richards    Male        Demimbu
# 15     16      Scott    Arnold    Male          Meemm
# ...

# %%
foods = pd.read_csv('foods.csv')
foods
# Out:
#     First Name  Gender          City Frequency       Item  Spend
# 0        Wanda  Female      Stamford    Weekly     Burger  15.66
# 1         Eric    Male      Stamford     Daily    Chalupa  10.56
# 2      Charles    Male      New York     Never      Sushi  42.14
# 3         Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4      Deborah  Female  Philadelphia     Daily    Chalupa  23.49
# 5      Charles    Male      Stamford   Monthly      Sushi  93.03
# 6         Mark    Male  Philadelphia   Monthly  Ice Cream  30.01
# 7         Paul    Male  Philadelphia   Monthly    Chalupa  17.65
# 8        Larry    Male      New York   Monthly     Burger  34.11
# 9        Roger    Male      Stamford   Monthly    Chalupa  39.01
# 10      Samuel    Male      Stamford     Daily  Ice Cream  15.17
# 11      Rachel  Female  Philadelphia    Seldom      Sushi  71.68
# 12        Mary  Female  Philadelphia      Once     Burger   1.97
# ...

# %% [markdown]
# **The pd.concat() Method**

# %%
week1 = pd.read_csv('Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Restaurant - Customers.csv')
foods = pd.read_csv('Restaurant - Foods.csv')

# %% [raw]
# Note: The concat() method combines two different dataframes

# %%
len(week1)
# Out:
# 250

# %%
len(week2)
# Out:
# 250

# %%
# The concatenation of week1 and week2 should result in a dataframe containing 500 rows in total

pd.concat([week1, week2]) # Here first 250 rows belong to week1 and the rest 250 belong to week2 because of the order in which
                            # they were passed
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 220          495        2
# 221          794        6
# 222          734       10
# ...

# %%
len(pd.concat([week1, week2])) # Even though we have 500 rows in the resulting dataframe, the last index value is 249. Explained below
# Out:
# 500

# %% [raw]
# Note: As you notice in above output, after concatenation, the rows 0 to 249 contain rows from week1 and then in the index column, the index starts again from 0 to 249 to join with rows from week2 dataframe. This is because the ignore_index parameter is set to false by default. When it's set to true, it maintains the count of the index and continues it beyond the point of join as well.
# Compare the index column of the below input with the one above

# %%
pd.concat([week1, week2], ignore_index=True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 470          495        2
# 471          794        6
# 472          734       10
# ...

# %% [raw]
# Note: The keys parameter takes in a list of string input of as many values as the number of dataframes being concatenated. It basically creates a multiindex dataframe where each string value passed in the list corresponds to the outer layer index to each dataframe being concatenated. See below:

# %%
pd.concat([week1, week2], keys=['Week 1', 'Week 2']) # Now we don't have to see by index number to check which dataframe the row belongs to
# Out:
#             Customer ID  Food ID
# Week 1 0            537        9
#        1             97        4
#        2            658        1
#        3            202        2
#        4            155        9
#        5            213        8
#        6            600        1
#        7            503        5
#        8             71        3
#        9            174        3
#        10           961        9
#        11           966        5
#        12           641        4
#        13           288        2
#        14           149        4
#        15           954        2
#        16           147        9
#        17           155        1
#        18           550        6
#        19           101        7
#        20           549        6
#        21            75        6
#        22            78        7
#        23           514        5
#        24           833        7
#        25           329        8
#        26           586       10
# ...

# %%
sales = pd.concat([week1, week2], keys=['Week 1', 'Week 2'])
sales.loc['Week 1'] # Returns all the rows from concatenated dataframe which belong to Week 1
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 220          147        8
# 221          745        4
# 222          184        3
# ...

# %%
sales.loc['Week 2'] # Returns all the rows from concatenated dataframe which belong to Week 1
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# 5            310        5
# 6            761        2
# 7            443        5
# 8            729        9
# 9            741        8
# 10           847        6
# 11           156       10
# 12           550        7
# 13           620       10
# 14           272        4
# 15           511        2
# 16             8        6
# 17           534        7
# 18           909        6
# 19           732        9
# 20           372        4
# 21           713        1
# 22           496        3
# 23           381        9
# 24            13        2
# 25           101        4
# 26           325        7
# 27           674        2
# 28           564        8
# 29           578        5
# ..           ...      ...
# 220          495        2
# 221          794        6
# 222          734       10
# ...

# %%
# If you want to fetch a record more specifically, we can pass a tupple into the loc[] method

sales.loc[('Week 1', 240)] # Passing both index values
# Out:
# Customer ID    945
# Food ID          5
# Name: (Week 1, 240), dtype: int64

# %%
# If you now want to fetch a specific column value within that record, pass a column name apart from the tupple as well

sales.loc[('Week 1', 240), 'Customer ID']
# Out:
# 945

# %% [markdown]
# **The .append() Method on a DataFrame**

# %%
week1 = pd.read_csv('Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Restaurant - Customers.csv')
foods = pd.read_csv('Restaurant - Foods.csv')

# %% [raw]
# Note: The append() method works exactly like the concat() method except it's called on a dataframe instead of passing both dataframes to one method (as is the case in concat() method)

# %%
week1.append(week2)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 220          495        2
# 221          794        6
# 222          734       10
# ...

# %%
week1.append(week2, ignore_index=True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 470          495        2
# 471          794        6
# 472          734       10
# ...

# %% [markdown]
# **Inner Joins**

# %%
import pandas as pd

week1 = pd.read_csv('Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Restaurant - Customers.csv')
foods = pd.read_csv('Restaurant - Foods.csv')

# %%
week1.head()
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
week2.head()
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10
# 3          189        5
# 4          267        3

# %% [raw]
# Note: Inner join is the same as the inner join we've read about in SQL, picking on the common columns between two dataframes. Here, the Customer ID is the common field. The dataframe on which merge() is called is the left df and the one being passed as argument to merge() is treated as right df.

# %%
week1.merge(week1, how='inner', on='Customer ID')
# Out:
#      Customer ID  Food ID_x  Food ID_y
# 0            537          9          9
# 1             97          4          4
# 2            658          1          1
# 3            202          2          2
# 4            155          9          9
# 5            155          9          1
# 6            155          1          9
# 7            155          1          1
# 8            213          8          8
# 9            600          1          1
# 10           503          5          5
# 11            71          3          3
# 12            71          3          8
# 13            71          8          3
# 14            71          8          8
# 15           174          3          3
# 16           961          9          9
# 17           966          5          5
# 18           641          4          4
# 19           288          2          2
# 20           149          4          4
# 21           954          2          2
# 22           147          9          9
# ...

# %% [raw]
# Note: Notice how Food ID column now exists as two columns, one from week1 dataframe and other from week2, where _x and _y are default pandas suffixes representing week1 and week2 dataframes respectively. We can change these suffix values while merging the dataframes as well, by passing a list of suffix values for each column

# %%
week = week1.merge(week2, how='inner', on='Customer ID', suffixes=[' - Week 1', ' - Week 2'])
week.head()
# Out:
#    Customer ID  Food ID - Week 1  Food ID - Week 2
# 0          537                 9                 5
# 1          155                 9                 3
# 2          155                 1                 3
# 3          503                 5                 8
# 4          503                 5                 9

# %% [raw]
# Notice how the index of the dataframe has repeating values, eg Customer ID 155. That's because this customer came to the restaurant twice in week 1 but only once in week 2. Which is why two records got created with same value for week 2 in both records to accomadate different values for week 1. We can verify this as well:

# %%
week1[ week1['Customer ID'] == 155 ] # Two values for index '155'
# Out:
#     Customer ID  Food ID
# 4           155        9
# 17          155        1

# %%
mask = week2['Customer ID'] == 155 
week2[ mask ]  # Single value for index = '155'
# Out:
#      Customer ID  Food ID
# 208          155        3

# %%
# Re-executing code

import pandas as pd

week1 = pd.read_csv('Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Restaurant - Customers.csv')
foods = pd.read_csv('Restaurant - Foods.csv')

# %%
week1.head()
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
week2.head()
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10
# 3          189        5
# 4          267        3

# %% [raw]
# Note: Now we'll try to obtain customers who came into the restauraunt in both week 1 and week 2 and oredered the same food

# %%
week1.merge(week2, how='inner', on=['Customer ID', 'Food ID'])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %% [raw]
# Note: There are no multiple columns or suffixes because only the common columns have been selected. Also, you might notice that their are still duplicate values in the merged dataframe. This is how they occur:

# %%
week1[ week1['Customer ID'] == 21 ] # See two occurences of Customer ID 21 in week 1 (meaning same customer ordered same food twice in first week)
# Out:
#      Customer ID  Food ID
# 101           21        4
# 212           21        4

# %%
week2[ week2['Customer ID'] == 21 ] # There's one occurence of the same customer ordering the same food in week 2
# Out:
#     Customer ID  Food ID
# 30           21        4

# %% [raw]
# Note: This is what happens. Week1 is the left df and week2 is the right df in the merge statement being executed. So the merge command spots the first row in the left df having customer id 21 and food id 4 and then looks for its duplicate in the right dataframe. Once it's found, it inludes it in the resultant df of merge statement. Then, in the next record in week1 (left) df, if again finds a record with Customer ID and Food ID as 21 and 4. Again, merge() looks for a dupicate in the week2 (right) df and once it's found, it includes it in the resultant df.

# %% [markdown]
# **Outer Joins**

# %%
import pandas as pd

week1 = pd.read_csv('Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Restaurant - Customers.csv')
foods = pd.read_csv('Restaurant - Foods.csv')

# %% [raw]
# Note: When using how parameter as 'outer', the default merge is Full Outer join.

# %%
week = week1.merge(week2, how='outer', on='Customer ID', suffixes=[' - Week 1', ' - Week 2'])
week # Would only contain all the uncommon and common elements between the two dataframe
# Out:
#      Customer ID  Food ID - Week 1  Food ID - Week 2
# 0            537               9.0               5.0
# 1             97               4.0               NaN
# 2            658               1.0               NaN
# 3            202               2.0               NaN
# 4            155               9.0               3.0
# 5            155               1.0               3.0
# 6            213               8.0               NaN
# 7            600               1.0               NaN
# 8            503               5.0               8.0
# 9            503               5.0               9.0
# 10            71               3.0               NaN
# 11            71               8.0               NaN
# 12           174               3.0               NaN
# 13           961               9.0               NaN
# 14           966               5.0               NaN
# 15           641               4.0               NaN
# 16           288               2.0               NaN
# ...

# %% [raw]
# Note: Rows with no null  values are common between the two dataframes here. Any row having null values signifies records unique to either week1 or week2 dataframe. To make it clearer which dataframe the value is being pulled from, we use the 'indicator' parameter

# %%
week = week1.merge(week2, how='outer', on=['Customer ID'], indicator=True)
week
# Out:
#      Customer ID  Food ID_x  Food ID_y      _merge
# 0            537        9.0        5.0        both
# 1             97        4.0        NaN   left_only
# 2            658        1.0        NaN   left_only
# 3            202        2.0        NaN   left_only
# 4            155        9.0        3.0        both
# 5            155        1.0        3.0        both
# 6            213        8.0        NaN   left_only
# 7            600        1.0        NaN   left_only
# 8            503        5.0        8.0        both
# 9            503        5.0        9.0        both
# 10            71        3.0        NaN   left_only
# 11            71        8.0        NaN   left_only
# 12           174        3.0        NaN   left_only
# 13           961        9.0        NaN   left_only
# 14           966        5.0        NaN   left_only
# 15           641        4.0        NaN   left_only
# 16           288        2.0        NaN   left_only
# ...

# %%
# We can use .value_counts() emmthod to analyse where the data is coming from
week['_merge'].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %%
mask = week['_merge'].isin(['left_only', 'right_only']) # To fetch only the uncommon records
week[mask]
# Out:
#      Customer ID  Food ID_x  Food ID_y      _merge
# 1             97        4.0        NaN   left_only
# 2            658        1.0        NaN   left_only
# 3            202        2.0        NaN   left_only
# 6            213        8.0        NaN   left_only
# 7            600        1.0        NaN   left_only
# 10            71        3.0        NaN   left_only
# 11            71        8.0        NaN   left_only
# 12           174        3.0        NaN   left_only
# 13           961        9.0        NaN   left_only
# 14           966        5.0        NaN   left_only
# 15           641        4.0        NaN   left_only
# 16           288        2.0        NaN   left_only
# 17           149        4.0        NaN   left_only
# 18           954        2.0        NaN   left_only
# 19           147        9.0        NaN   left_only
# 20           147        8.0        NaN   left_only
# 23           549        6.0        NaN   left_only
# ...

# %% [markdown]
# **Left Join**

# %%
import pandas as pd

week1 = pd.read_csv('Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Restaurant - Customers.csv')
foods = pd.read_csv('Restaurant - Foods.csv')

# %% [raw]
# Note: Combines all columns for two dataframes for all records in the left dataframe, whether shared or unshared. If a record is only present in the left dataframe but not in the right one, it is added to the merged df with null values.

# %%
merged = week1.merge(foods, how='left', on='Food ID')
merged
# Out:
#      Customer ID  Food ID   Food Item  Price
# 0            537        9       Donut   0.99
# 1             97        4  Quesadilla   4.25
# 2            658        1       Sushi   3.99
# 3            202        2     Burrito   9.99
# 4            155        9       Donut   0.99
# 5            213        8       Salad  11.25
# 6            600        1       Sushi   3.99
# 7            503        5       Pizza   2.49
# 8             71        3        Taco   2.99
# 9            174        3        Taco   2.99
# 10           961        9       Donut   0.99
# 11           966        5       Pizza   2.49
# 12           641        4  Quesadilla   4.25
# 13           288        2     Burrito   9.99
# 14           149        4  Quesadilla   4.25
# 15           954        2     Burrito   9.99
# 16           147        9       Donut   0.99
# 17           155        1       Sushi   3.99
# 18           550        6       Pasta  13.99
# 19           101        7       Steak  24.99
# ...

# %%
# Using the sort parameter sorts the records based on the column on which the two dataframes are being joined
merged = week1.merge(foods, how='left', on='Food ID', sort=True)
merged
# Out:
#      Customer ID  Food ID Food Item  Price
# 0            658        1     Sushi   3.99
# 1            600        1     Sushi   3.99
# 2            155        1     Sushi   3.99
# 3            341        1     Sushi   3.99
# 4             20        1     Sushi   3.99
# 5             77        1     Sushi   3.99
# 6            100        1     Sushi   3.99
# 7            953        1     Sushi   3.99
# 8            504        1     Sushi   3.99
# 9            323        1     Sushi   3.99
# 10           922        1     Sushi   3.99
# 11           909        1     Sushi   3.99
# 12           602        1     Sushi   3.99
# 13            74        1     Sushi   3.99
# 14           703        1     Sushi   3.99
# 15           962        1     Sushi   3.99
# 16           968        1     Sushi   3.99
# 17           190        1     Sushi   3.99
# 18           163        1     Sushi   3.99
# 19           321        1     Sushi   3.99
# 20           310        1     Sushi   3.99
# ...

# %% [markdown]
# **The left_on and right_on Parameters**

# %%
import pandas as pd

week1 = pd.read_csv('Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Restaurant - Customers.csv')
foods = pd.read_csv('Restaurant - Foods.csv')

# %%
customers.head()
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive
# 3   4     Steven     Evans    Male     Fatz               Registered Nurse
# 4   5       Judy  Morrison  Female  Demivee                Legal Assistant

# %%
week2.head()
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10
# 3          189        5
# 4          267        3

# %% [raw]
# Note: These parameters come in handy while merging two dataframes on a column having different name in each dataframe. Suppose we want to merge week2 and customer dataframe, where Customer ID column in week2 is names simply ID in customers df.

# %%
week2.merge(customers, how='left', left_on='Customer ID', right_on='ID')
# Out:
#      Customer ID  Food ID   ID   First Name   Last Name  Gender       Company  \
# 0            688       10  688         Carl  Williamson    Male    Thoughtmix
# 1            813        7  813       Johnny      Walker    Male        Kayveo
# 2            495       10  495      Deborah      Little  Female    Babbleblab
# 3            189        5  189        Roger      Gordon    Male       Skilith
# 4            267        3  267      Matthew        Wood    Male        Agimba
# 5            310        5  310        Bobby        Sims    Male     Skynoodle
# 6            761        2  761    Stephanie       Olson  Female     Rhynoodle
# 7            443        5  443       Robert    Thompson    Male          Oozz
# 8            729        9  729        Roger    Lawrence    Male        Wikizz
# 9            741        8  741        Diana       Welch  Female          Eayo
# 10           847        6  847        Irene       Owens  Female         Yabox
# ...

# %% [raw]
# Note: In the above output, notice how the same column from both dataframes, Cutomer ID and ID, has been loaded twice in the resultant df. This is useful to confirm that mapping has been done successfully while merging but is not needed otherwise. here's how you get rid of it:

# %%
week2.merge(customers, how='left', left_on='Customer ID', right_on='ID').drop("ID", axis='columns') 
# We have to pass axis='columns' to drop() because it searches in axis='index' by default
# Out:
#      Customer ID  Food ID   First Name   Last Name  Gender       Company  \
# 0            688       10         Carl  Williamson    Male    Thoughtmix
# 1            813        7       Johnny      Walker    Male        Kayveo
# 2            495       10      Deborah      Little  Female    Babbleblab
# 3            189        5        Roger      Gordon    Male       Skilith
# 4            267        3      Matthew        Wood    Male        Agimba
# 5            310        5        Bobby        Sims    Male     Skynoodle
# 6            761        2    Stephanie       Olson  Female     Rhynoodle
# 7            443        5       Robert    Thompson    Male          Oozz
# 8            729        9        Roger    Lawrence    Male        Wikizz
# 9            741        8        Diana       Welch  Female          Eayo
# 10           847        6        Irene       Owens  Female         Yabox
# 11           156       10    Stephanie       Kelly  Female       Youopia
# ...
